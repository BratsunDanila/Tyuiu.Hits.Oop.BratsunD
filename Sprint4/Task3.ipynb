// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) создайте явную реализации интерфейса и управление зависимостями

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
interface IFired
{
    public void Fired();
}

public interface IEmployee
{
    void Fired(int cashback);
    void Work();
    string GetInfo();
    void TakeVacation();
    void Display();
    void VacationCheck(bool isOnVacation);
    void ChangeSalary(int change);
}

public class Employee: IEmployee
{
    private string name;
    private int salary;
    private int age;

    public int Age
    {
        get { return age; }
        set
        {
            if (value > 0)
                age = value;
            else
                throw new ArgumentOutOfRangeException("Возраст не может быть отрицательным!");
        }
    }

    public int Salary
    {
        get { return salary; }
        set
        {
            if (value > 0)
                salary = value;
            else
                throw new ArgumentOutOfRangeException("Зарплата не может быть отрицательной!");
        }
    }
    public string Name
    {
        get { return name; }
        set {name = value; }
    }

    public Employee(string name, int age, int salary)
    {
        Name = name;
        Age = age;
        Salary = salary;
    }

    void IEmployee.Fired(int cashback)
    {
        Console.WriteLine($"Сотрудник {Name} уволен, необходимо выплатить ему {cashback} рублей.");
    }


    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Зарплата: {Salary} рублей";
    }

    void IEmployee.Work()
    {
        Console.WriteLine($"Сотрудник {Name} работает");
    }

    void IEmployee.TakeVacation()
    {
        Console.WriteLine($"Сотрудник {Name} взял отпуск");
    }

    public virtual void TakeVacation(int date)
    {
        Console.WriteLine($"Сотрудник {Name} взял отпуск на {date} дней");
    }

    void IEmployee.Display()
    {
        Console.WriteLine(GetInfo());
    }

    public virtual void Compare(Employee otherEmployee)
    {
        int priceDifference = this.Salary - otherEmployee.Salary;
        if (Salary < otherEmployee.Salary)
        {
            Console.WriteLine ($"{Name} зарабатывает меньше, чем {otherEmployee.Name} на {-priceDifference} руб.");
        }
        else if (Salary > otherEmployee.Salary)
        {
            Console.WriteLine ($"{Name} зарабатывает больше, чем {otherEmployee.Name} на {priceDifference} руб.");
        }
        else
        {
            Console.WriteLine ($"{Name} и {otherEmployee.Name} имеют одинаковую зарплату.");
        }
    }

    void IEmployee.VacationCheck(bool isOnVacation)
    {
        if(isOnVacation)
        {
            Console.WriteLine($"Сотрудник {Name} находится в отпуске.");
        }
        else
        {
            Console.WriteLine($"Сотрудник {Name} не в отпуске.");
        }
    }
    void IEmployee.ChangeSalary(int change)
    {
        Salary += change;
        Console.WriteLine($"Зарплата сотрудника {Name} изменилась и составляет {Salary} руб.");

    }
}

public class EmployeeList<T> where T : Employee
{
    private List<T> employees = new List<T>();

    public void AddEmployee(T employee)
    {
        employees.Add(employee);
        Console.WriteLine($"Сотрудник {employee.Name} добавлен в список.");
    }

    public void RemoveEmployee(T employee)
    {
        if (employees.Remove(employee))
        {
            Console.WriteLine($"Сотрудник {employee.Name} удален из списка.");
        }
        else
        {
            Console.WriteLine($"Сотрудник {employee.Name} не найден в списке.");
        }
    }

    public void DisplayAll()
    {
        foreach (var employee in employees)
        {
            employee.Display();
        }
    }
}

public class Manager : Employee
{
    public int SubordinatesCount { get; set; }

    public Manager(string name, int age, int salary, int subordinatescount) : base (name, age, salary)
    {
        SubordinatesCount = subordinatescount;
    }

    public void Work()
    {
        Console.WriteLine($"Менеджер {Name} управляет командой");
    }

    public void Display()
    {
        Console.WriteLine($"Менеджер - {GetInfo()}, Количество подчиненных: {SubordinatesCount}");
    }
    
    public void TakeVacation()
    {
        Console.WriteLine($"Менеджер {Name} взял отпуск");
    }

}

public class Developer : Employee
{
    public string Specialization { get; set; }

    public Developer(string name, int age, int salary, string specialization) : base (name, age, salary)
    {
        Specialization = specialization;
    }

    public void TakeVacation()
    {
        Console.WriteLine($"Разработчик {Name} взял отпуск, его необходимо согласовать с проектными сроками!!!");
    }

    public void Display()
    {
        Console.WriteLine($"Разработчик - {GetInfo()}, Специализация: {Specialization}");
    }

}

public class GameDeveloper : Developer, IFired
{

    public string Genre { get; set; }

    public GameDeveloper(string name, int age, int salary, string specialization, string genre) : base (name, age, salary, specialization)
    {
        Genre = genre;
    }

    public void TakeVacation()
    {
        Console.WriteLine($"Разработчик игр {Name} взял отпуск, его необходимо согласовать с проектными сроками!!!");
    }

    public void Display()
    {
        Console.WriteLine($"Разработчик игр - {GetInfo()}, Жанр игр: {Genre}");
    }

    public void Fired()
    {
        Console.WriteLine($"Разработчик игр {Name} УВОЛЕН!!!");
    }

}

public class Designer : Employee, IFired
{
    public string DesignStyle { get; set; }

    public Designer(string name, int age, int salary, string designstyle) : base (name, age, salary)
    {
        DesignStyle = designstyle;
    }

    public void Work()
    {
        Console.WriteLine($"Дизайнер {Name} работает над дизайн-проектом №1");
    }

    public void Display()
    {
        Console.WriteLine($"Дизайнер - {GetInfo()}, Стиль дизайна: {DesignStyle}");
    }

    public void Fired()
    {
        Console.WriteLine($"Дизайнер {Name} УВОЛЕН!!! Необходимо внести этого сотрудника в черный список дизайнеров");
    }

}

public class EmployeeService //управление зависимостями
{
    private readonly IEmployee _employee;

    
    public EmployeeService(IEmployee employee)
    {
        _employee = employee; 
    }

    public void Info(bool isOnVacation)
    {
        _employee.Display();
        _employee.VacationCheck(isOnVacation);
    }

    public void ChangeSalary(int change)
    {
        _employee.ChangeSalary(change);
    }

}

//Employee first = new Manager("Иван", 34, 250000, 30);
//Employee second = new Developer("Василий", 27, 120000, "Back-End");
//GameDeveloper forth = new GameDeveloper("Эдуард", 24, 80000, "", "Инди");
//Designer third = new Designer("Ксения", 25 , 150000, "Стиль Аниме");
//Employee forth = new Developer("Максим", -10 , -555, "Front-End");

//first.Display(); first.Work(); first.TakeVacation(90);
//second.Display(); second.TakeVacation();
//third.Display(); third.Work(); third.Fired(); third.Fired(50000);
//forth.Display(); forth.Fired();
//first.Compare(third);


EmployeeList<Employee> employeeList = new EmployeeList<Employee>();

Manager first = new Manager("Иван", 34, 250000, 30);
Developer second = new Developer("Василий", 27, 120000, "Back-End");
Designer third = new Designer("Ксения", 25 , 150000, "Стиль Аниме");
GameDeveloper forth = new GameDeveloper("Эдуард", 24, 80000, "", "Инди");
EmployeeService employeeService = new EmployeeService(first);

employeeList.AddEmployee(first);
employeeList.AddEmployee(second);
employeeList.AddEmployee(forth);
employeeList.AddEmployee(third);

Console.WriteLine("\nСписок сотрудников:");
employeeList.DisplayAll();

employeeList.RemoveEmployee(third);
employeeList.RemoveEmployee(third);

Console.WriteLine("\nОбновленный список сотрудников:");
employeeList.DisplayAll();

first.TakeVacation(50000);
first.TakeVacation();
forth.TakeVacation();

employeeService.Info(false);
employeeService.ChangeSalary(5000);
employeeService.Info(true);
// Out:
// Сотрудник Иван добавлен в список.
// Сотрудник Василий добавлен в список.
// Сотрудник Эдуард добавлен в список.
// Сотрудник Ксения добавлен в список.
//
// Список сотрудников:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+Manager</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>SubordinatesCount</td><td><div class="dni-plaintext"><pre>30</pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>34</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>250000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Иван</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+Developer</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Specialization</td><td><div class="dni-plaintext"><pre>Back-End</pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>27</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>120000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Василий</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+GameDeveloper</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Genre</td><td><div class="dni-plaintext"><pre>Инди</pre></div></td></tr><tr><td>Specialization</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>24</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>80000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Эдуард</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+Designer</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>DesignStyle</td><td><div class="dni-plaintext"><pre>Стиль Аниме</pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>25</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>150000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Ксения</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// Сотрудник Ксения удален из списка.
// Сотрудник Ксения не найден в списке.
//
// Обновленный список сотрудников:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+Manager</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>SubordinatesCount</td><td><div class="dni-plaintext"><pre>30</pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>34</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>250000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Иван</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+Developer</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Specialization</td><td><div class="dni-plaintext"><pre>Back-End</pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>27</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>120000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Василий</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#38+GameDeveloper</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Genre</td><td><div class="dni-plaintext"><pre>Инди</pre></div></td></tr><tr><td>Specialization</td><td><div class="dni-plaintext"><pre></pre></div></td></tr><tr><td>Age</td><td><div class="dni-plaintext"><pre>24</pre></div></td></tr><tr><td>Salary</td><td><div class="dni-plaintext"><pre>80000</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Эдуард</pre></div></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
// Сотрудник Иван взял отпуск на 50000 дней
// Менеджер Иван взял отпуск
// Разработчик игр Эдуард взял отпуск, его необходимо согласовать с проектными сроками!!!
// Имя: Иван, Возраст: 34, Зарплата: 250000 рублей
// Сотрудник Иван не в отпуске.
// Зарплата сотрудника Иван изменилась и составляет 255000 руб.
// Имя: Иван, Возраст: 34, Зарплата: 255000 рублей
// Сотрудник Иван находится в отпуске.
